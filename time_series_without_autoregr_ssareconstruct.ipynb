# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import pylab
import warnings as w
import os
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_auc_score
from itertools import cycle

# %matplotlib inline

# %%
import matplotlib
matplotlib.rcParams.update({'font.size':14})

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# !unzip UCI\ HAR\ Dataset.zip

# %%
X_train_with_engineered_features = np.genfromtxt(os.path.join("UCI HAR Dataset", "train", "X_train.txt"))
y_train = np.genfromtxt(os.path.join("UCI HAR Dataset", "train", "y_train.txt"))

y_train_list = list(y_train)
X_unique = np.array([X_train_with_engineered_features[y_train_list.index(l)]
                             for l in sorted(list(set(y_train)))])

legend_labels = ["WALKING", "WALKING.UP", "WALKING.DOWN", "SITTING", "STANDING", "LAYING"]
colors_list = ['red', 'blue', 'green', 'orange', 'cyan', 'magenta']
mapped_colors = [colors_list[int(i)-1] for i in y_train]

from sklearn.decomposition import PCA
pca = PCA()

X_train_pca = pca.fit_transform(X_train_with_engineered_features)

plt.figure(figsize=(15,10))
pylab.scatter(X_train_pca[:, 0], X_train_pca[:, 1],
             c=mapped_colors)
plt.grid()
for idx, x in enumerate(pca.transform(X_unique)):
    plt.scatter(x[0], 
                x[1], 
                c=colors_list[idx], 
                label=legend_labels[idx])
plt.xlabel('First principal component')
plt.ylabel('Second principal component')
plt.legend()

# %%
# Useful Constants

# Those are separate normalised input features for the neural network
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

# Output classes to learn how to classify
LABELS = [
    "WALKING", 
    "WALKING_UPSTAIRS", 
    "WALKING_DOWNSTAIRS", 
    "SITTING", 
    "STANDING", 
    "LAYING"
]

DATA_PATH = "./"

DATASET_PATH = DATA_PATH + "UCI HAR Dataset/"
print("\n" + "Dataset is now located at: " + DATASET_PATH)

TRAIN = "train/"
TEST = "test/"


# Load "X" (the neural network's training and testing inputs)

def load_X(X_signals_paths):
    X_signals = []
    
    for signal_type_path in X_signals_paths:
        file = open(signal_type_path, 'r')
        # Read dataset from disk, dealing with text files' syntax
        X_signals.append(
            [np.array(serie, dtype=np.float32) for serie in [
                row.replace('  ', ' ').strip().split(' ') for row in file
            ]]
        )
        file.close()
    
    return np.transpose(np.array(X_signals), (1, 2, 0))

X_train_signals_paths = [
    os.path.join(*[DATASET_PATH, TRAIN, "Inertial Signals/", signal+"train.txt"]) for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    os.path.join(*[DATASET_PATH, TEST, "Inertial Signals/", signal+"test.txt"]) for signal in INPUT_SIGNAL_TYPES
]

X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)


# Load "y" (the neural network's training and testing outputs)

def load_y(y_path):
    file = open(y_path, 'r')
    # Read dataset from disk, dealing with text file's syntax
    y_ = np.array(
        [elem for elem in [
            row.replace('  ', ' ').strip().split(' ') for row in file
        ]], 
        dtype=np.int32
    )
    file.close()
    
    # Substract 1 to each output class for friendly 0-based indexing 
    return y_ - 1

y_train_path = os.path.join(DATASET_PATH, TRAIN, "y_train.txt")
y_test_path = os.path.join(DATASET_PATH, TEST, "y_test.txt")

y_train = load_y(y_train_path)
y_test = load_y(y_test_path)
# Out:
# Dataset is now located at: ./UCI HAR Dataset/

# %%
# Input Data 

training_data_count = len(X_train)  # 7352 training series (with 50% overlap between each serie)
test_data_count = len(X_test)  # 2947 testing series
n_steps = len(X_train[0])  # 128 timesteps per series
n_input = len(X_train[0][0])  # 9 input parameters per timestep


# LSTM Neural Network's internal structure

n_hidden = 32 # Hidden layer num of features
n_classes = 6 # Total classes (should go up, or should go down)


# Some debugging info

print("Some useful info to get an insight on dataset's shape and normalisation:")
print("(X shape, y shape, every X's mean, every X's standard deviation)")
print(X_test.shape, y_test.shape, np.mean(X_test), np.std(X_test))
print("The dataset is therefore properly normalised, as expected, but not yet one-hot encoded.")
# Out:
# Some useful info to get an insight on dataset's shape and normalisation:
# (X shape, y shape, every X's mean, every X's standard deviation)
# (2947, 128, 9) (2947, 1) 0.09913992 0.39567086
# The dataset is therefore properly normalised, as expected, but not yet one-hot encoded.

# %%
class SSA(object):
    
    __supported_types = (pd.Series, np.ndarray, list)
    
    def __init__(self, tseries, L, save_mem=True):
        """
        Decomposes the given time series with a singular-spectrum analysis. Assumes the values of the time series are
        recorded at equal intervals.
        
        Parameters
        ----------
        tseries : The original time series, in the form of a Pandas Series, NumPy array or list. 
        L : The window length. Must be an integer 2 <= L <= N/2, where N is the length of the time series.
        save_mem : Conserve memory by not retaining the elementary matrices. Recommended for long time series with
            thousands of values. Defaults to True.
        
        Note: Even if an NumPy array or list is used for the initial time series, all time series returned will be
        in the form of a Pandas Series or DataFrame object.
        """
        
        # Tedious type-checking for the initial time series
        if not isinstance(tseries, self.__supported_types):
            raise TypeError("Unsupported time series object. Try Pandas Series, NumPy array or list.")
        
        # Checks to save us from ourselves
        self.N = len(tseries)
        if not 2 <= L <= self.N/2:
            raise ValueError("The window length must be in the interval [2, N/2].")
        
        self.L = L
        self.orig_TS = pd.Series(tseries)
        self.K = self.N - self.L + 1
        
        # Embed the time series in a trajectory matrix
        self.X = np.array([self.orig_TS.values[i:L+i] for i in range(0, self.K)]).T
        
        # Decompose the trajectory matrix
        self.U, self.Sigma, VT = np.linalg.svd(self.X)
        self.d = np.linalg.matrix_rank(self.X)
        
        self.TS_comps = np.zeros((self.N, self.d))
        
        if not save_mem:
            # Construct and save all the elementary matrices
            self.X_elem = np.array([ self.Sigma[i]*np.outer(self.U[:,i], VT[i,:]) for i in range(self.d) ])

            # Diagonally average the elementary matrices, store them as columns in array.           
            for i in range(self.d):
                X_rev = self.X_elem[i, ::-1]
                self.TS_comps[:,i] = [X_rev.diagonal(j).mean() for j in range(-X_rev.shape[0]+1, X_rev.shape[1])]
            
            self.V = VT.T
        else:
            # Reconstruct the elementary matrices without storing them
            for i in range(self.d):
                X_elem = self.Sigma[i]*np.outer(self.U[:,i], VT[i,:])
                X_rev = X_elem[::-1]
                self.TS_comps[:,i] = [X_rev.diagonal(j).mean() for j in range(-X_rev.shape[0]+1, X_rev.shape[1])]
            
            self.X_elem = "Re-run with save_mem=False to retain the elementary matrices."
            
            # The V array may also be very large under these circumstances, so we won't keep it.
            self.V = "Re-run with save_mem=False to retain the V matrix."
        
        # Calculate the w-correlation matrix.
        self.calc_wcorr()
            
    def components_to_df(self, n=0):
        """
        Returns all the time series components in a single Pandas DataFrame object.
        """
        if n > 0:
            n = min(n, self.d)
        else:
            n = self.d
        
        # Create list of columns - call them F0, F1, F2, ...
        cols = ["F{}".format(i) for i in range(n)]
        return pd.DataFrame(self.TS_comps[:, :n], columns=cols, index=self.orig_TS.index)
            
    
    def reconstruct(self, indices):
        """
        Reconstructs the time series from its elementary components, using the given indices. Returns a Pandas Series
        object with the reconstructed time series.
        
        Parameters
        ----------
        indices: An integer, list of integers or slice(n,m) object, representing the elementary components to sum.
        """
        if isinstance(indices, int): indices = [indices]
        
        ts_vals = self.TS_comps[:,indices].sum(axis=1)
        return pd.Series(ts_vals, index=self.orig_TS.index)
    
    def calc_wcorr(self):
        """
        Calculates the w-correlation matrix for the time series.
        """
             
        # Calculate the weights
        w = np.array(list(np.arange(self.L)+1) + [self.L]*(self.K-self.L-1) + list(np.arange(self.L)+1)[::-1])
        
        def w_inner(F_i, F_j):
            return w.dot(F_i*F_j)
        
        # Calculated weighted norms, ||F_i||_w, then invert.
        F_wnorms = np.array([w_inner(self.TS_comps[:,i], self.TS_comps[:,i]) for i in range(self.d)])
        F_wnorms = F_wnorms**-0.5
        
        # Calculate Wcorr.
        self.Wcorr = np.identity(self.d)
        for i in range(self.d):
            for j in range(i+1,self.d):
                self.Wcorr[i,j] = abs(w_inner(self.TS_comps[:,i], self.TS_comps[:,j]) * F_wnorms[i] * F_wnorms[j])
                self.Wcorr[j,i] = self.Wcorr[i,j]
    
    def plot_wcorr(self, min=None, max=None):
        """
        Plots the w-correlation matrix for the decomposed time series.
        """
        if min is None:
            min = 0
        if max is None:
            max = self.d
        
        if self.Wcorr is None:
            self.calc_wcorr()
        
        ax = plt.imshow(self.Wcorr)
        plt.xlabel(r"$\tilde{F}_i$")
        plt.ylabel(r"$\tilde{F}_j$")
        plt.colorbar(ax.colorbar, fraction=0.045)
        ax.colorbar.set_label("$W_{i,j}$")
        plt.clim(0,1)
        
        # For plotting purposes:
        if max == self.d:
            max_rnge = self.d-1
        else:
            max_rnge = max
        
        plt.xlim(min-0.5, max_rnge+0.5)
        plt.ylim(max_rnge+0.5, min-0.5)

# %%
# %%time
X_train_new = np.array([])
for x in X_train:
    x = x.reshape(9, 128)
    a = np.array([])
    for t in x:
        F_ssa_L5 = SSA(t, 5)
        series = {}
        for i in range(5):
            for j in range(5):
                if F_ssa_L5.Wcorr[i][j] > 0.3 and i < j:
                    if i in series:
                        series[i].append(j)
                    else:
                        series[i] = [j]
                        series[i].append(i)
        slices = [value for value in series.values()]
        for s in slices:
            if len(a) != 0:
                a = np.append(a, F_ssa_L5.reconstruct(s).to_numpy().reshape(1, 128), axis=0)
            else:
                a = F_ssa_L5.reconstruct(s).to_numpy().reshape(1, 128)
    if len(X_train_new) != 0:
        X_train_new = np.append(X_train_new, a[:20].reshape(1,20,128), axis=0)
    else:
        X_train_new = a[:20].reshape(1,20,128)
# Out:
# CPU times: user 15min 36s, sys: 11min 10s, total: 26min 47s
# Wall time: 13min 36s

# %%
# %%time
X_test_new = np.array([])
for x in X_test:
    x = x.reshape(9, 128)
    a = np.array([])
    for t in x:
        F_ssa_L5 = SSA(t, 5)
        series = {}
        for i in range(5):
            for j in range(5):
                if F_ssa_L5.Wcorr[i][j] > 0.3 and i < j:
                    if i in series:
                        series[i].append(j)
                    else:
                        series[i] = [j]
                        series[i].append(i)
        slices = [value for value in series.values()]
        for s in slices:
            if len(a) != 0:
                a = np.append(a, F_ssa_L5.reconstruct(s).to_numpy().reshape(1, 128), axis=0)
            else:
                a = F_ssa_L5.reconstruct(s).to_numpy().reshape(1, 128)
    if len(X_test_new) != 0:
        X_test_new = np.append(X_test_new, a[:20].reshape(1,20,128), axis=0)
    else:
        X_test_new = a[:20].reshape(1,20,128)
# Out:
# CPU times: user 5min 24s, sys: 3min 48s, total: 9min 12s
# Wall time: 4min 41s

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.utils import to_categorical
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
X_train_new = X_train_new.reshape(X_train_new.shape[0], 1, 32, 80)
X_train_new = X_train_new.astype('float32')
X_train_new /= np.amax(X_train_new)
y_train_new = y_train.reshape(-1)
Y_train_new = np_utils.to_categorical(y_train_new, 6)

# %%
X_test_new = X_test_new.reshape(X_test_new.shape[0], 1, 32, 80)
X_test_new = X_test_new.astype('float32')
X_test_new /= np.amax(X_test_new)
y_test_new = y_test.reshape(-1)
Y_test_new = np_utils.to_categorical(y_test_new, 6)

# %%
model = Sequential()
 
model.add(Convolution2D(32, (3, 3), activation='relu', input_shape=(1,32,80), data_format='channels_first'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Convolution2D(32, (3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25)) 
model.add(Flatten())
model.add(Dense(64, activation='relu'))
#model.add(LeakyReLU(alpha=0.03))
model.add(Dropout(0.5))
model.add(Dense(6, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# %%time
model.fit(X_train_new, Y_train_new, epochs=100, validation_split=0.1, batch_size=16,shuffle=True)
# Out:
# Epoch 1/100
# 414/414 [==============================] - 2s 5ms/step - loss: 1.0656 - accuracy: 0.5343 - val_loss: 0.6656 - val_accuracy: 0.6576
# Epoch 2/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.6677 - accuracy: 0.6947 - val_loss: 0.6361 - val_accuracy: 0.6861
# Epoch 3/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.5930 - accuracy: 0.7376 - val_loss: 0.6712 - val_accuracy: 0.7188
# Epoch 4/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.5269 - accuracy: 0.7817 - val_loss: 0.5232 - val_accuracy: 0.7731
# Epoch 5/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.4763 - accuracy: 0.8094 - val_loss: 0.4587 - val_accuracy: 0.8207
# Epoch 6/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.4477 - accuracy: 0.8229 - val_loss: 0.5044 - val_accuracy: 0.7853
# Epoch 7/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.3795 - accuracy: 0.8514 - val_loss: 0.4714 - val_accuracy: 0.8016
# Epoch 8/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.3640 - accuracy: 0.8626 - val_loss: 0.3805 - val_accuracy: 0.8410
# Epoch 9/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.3370 - accuracy: 0.8742 - val_loss: 0.4170 - val_accuracy: 0.8247
# Epoch 10/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.3035 - accuracy: 0.8869 - val_loss: 0.4279 - val_accuracy: 0.8315
# Epoch 11/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2871 - accuracy: 0.8916 - val_loss: 0.3643 - val_accuracy: 0.8587
# Epoch 12/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2687 - accuracy: 0.8972 - val_loss: 0.3421 - val_accuracy: 0.8614
# Epoch 13/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2629 - accuracy: 0.9005 - val_loss: 0.3528 - val_accuracy: 0.8628
# Epoch 14/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2447 - accuracy: 0.9135 - val_loss: 0.3188 - val_accuracy: 0.8641
# Epoch 15/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2345 - accuracy: 0.9105 - val_loss: 0.3557 - val_accuracy: 0.8573
# Epoch 16/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2279 - accuracy: 0.9164 - val_loss: 0.3259 - val_accuracy: 0.8682
# Epoch 17/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2223 - accuracy: 0.9151 - val_loss: 0.3720 - val_accuracy: 0.8424
# Epoch 18/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2103 - accuracy: 0.9176 - val_loss: 0.2903 - val_accuracy: 0.8804
# Epoch 19/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2125 - accuracy: 0.9190 - val_loss: 0.3403 - val_accuracy: 0.8614
# Epoch 20/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2037 - accuracy: 0.9249 - val_loss: 0.3376 - val_accuracy: 0.8655
# Epoch 21/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1904 - accuracy: 0.9276 - val_loss: 0.4254 - val_accuracy: 0.8519
# Epoch 22/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1873 - accuracy: 0.9267 - val_loss: 0.4127 - val_accuracy: 0.8505
# Epoch 23/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1776 - accuracy: 0.9336 - val_loss: 0.3748 - val_accuracy: 0.8614
# Epoch 24/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1721 - accuracy: 0.9317 - val_loss: 0.2569 - val_accuracy: 0.8859
# Epoch 25/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1676 - accuracy: 0.9379 - val_loss: 0.2725 - val_accuracy: 0.8859
# Epoch 26/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1603 - accuracy: 0.9394 - val_loss: 0.3023 - val_accuracy: 0.8845
# Epoch 27/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1642 - accuracy: 0.9364 - val_loss: 0.3312 - val_accuracy: 0.8655
# Epoch 28/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1635 - accuracy: 0.9385 - val_loss: 0.2870 - val_accuracy: 0.8886
# Epoch 29/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1622 - accuracy: 0.9380 - val_loss: 0.3350 - val_accuracy: 0.8682
# Epoch 30/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1462 - accuracy: 0.9424 - val_loss: 0.3966 - val_accuracy: 0.8696
# Epoch 31/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1551 - accuracy: 0.9400 - val_loss: 0.3399 - val_accuracy: 0.8872
# Epoch 32/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1460 - accuracy: 0.9414 - val_loss: 0.3876 - val_accuracy: 0.8641
# Epoch 33/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1538 - accuracy: 0.9395 - val_loss: 0.3583 - val_accuracy: 0.8709
# Epoch 34/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1519 - accuracy: 0.9407 - val_loss: 0.2944 - val_accuracy: 0.8777
# Epoch 35/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1417 - accuracy: 0.9460 - val_loss: 0.3290 - val_accuracy: 0.8899
# Epoch 36/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1507 - accuracy: 0.9435 - val_loss: 0.3407 - val_accuracy: 0.8859
# Epoch 37/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1428 - accuracy: 0.9447 - val_loss: 0.3466 - val_accuracy: 0.8859
# Epoch 38/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1396 - accuracy: 0.9472 - val_loss: 0.3468 - val_accuracy: 0.8804
# Epoch 39/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1275 - accuracy: 0.9503 - val_loss: 0.3957 - val_accuracy: 0.8736
# Epoch 40/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1368 - accuracy: 0.9438 - val_loss: 0.4858 - val_accuracy: 0.8478
# Epoch 41/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1278 - accuracy: 0.9482 - val_loss: 0.4974 - val_accuracy: 0.8560
# Epoch 42/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1341 - accuracy: 0.9439 - val_loss: 0.3366 - val_accuracy: 0.8750
# Epoch 43/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1340 - accuracy: 0.9491 - val_loss: 0.3173 - val_accuracy: 0.8940
# Epoch 44/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1197 - accuracy: 0.9504 - val_loss: 0.3487 - val_accuracy: 0.8764
# Epoch 45/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1279 - accuracy: 0.9534 - val_loss: 0.4013 - val_accuracy: 0.8750
# Epoch 46/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1238 - accuracy: 0.9504 - val_loss: 0.2856 - val_accuracy: 0.8859
# Epoch 47/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1235 - accuracy: 0.9509 - val_loss: 0.3643 - val_accuracy: 0.8791
# Epoch 48/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1179 - accuracy: 0.9509 - val_loss: 0.4121 - val_accuracy: 0.8696
# Epoch 49/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1191 - accuracy: 0.9509 - val_loss: 0.3360 - val_accuracy: 0.8927
# Epoch 50/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1256 - accuracy: 0.9492 - val_loss: 0.3697 - val_accuracy: 0.8804
# Epoch 51/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1160 - accuracy: 0.9544 - val_loss: 0.3782 - val_accuracy: 0.8668
# Epoch 52/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1214 - accuracy: 0.9536 - val_loss: 0.4216 - val_accuracy: 0.8696
# Epoch 53/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1176 - accuracy: 0.9551 - val_loss: 0.4195 - val_accuracy: 0.8723
# Epoch 54/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1182 - accuracy: 0.9530 - val_loss: 0.4312 - val_accuracy: 0.8723
# Epoch 55/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1136 - accuracy: 0.9534 - val_loss: 0.3730 - val_accuracy: 0.8804
# Epoch 56/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1237 - accuracy: 0.9512 - val_loss: 0.3815 - val_accuracy: 0.8777
# Epoch 57/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1075 - accuracy: 0.9606 - val_loss: 0.4139 - val_accuracy: 0.8886
# Epoch 58/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1183 - accuracy: 0.9518 - val_loss: 0.4926 - val_accuracy: 0.8723
# Epoch 59/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1163 - accuracy: 0.9553 - val_loss: 0.3916 - val_accuracy: 0.8967
# Epoch 60/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1146 - accuracy: 0.9562 - val_loss: 0.4176 - val_accuracy: 0.8587
# Epoch 61/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1136 - accuracy: 0.9534 - val_loss: 0.3656 - val_accuracy: 0.8818
# Epoch 62/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1079 - accuracy: 0.9554 - val_loss: 0.3180 - val_accuracy: 0.8927
# Epoch 63/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1019 - accuracy: 0.9574 - val_loss: 0.3592 - val_accuracy: 0.8832
# Epoch 64/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1123 - accuracy: 0.9565 - val_loss: 0.4458 - val_accuracy: 0.8614
# Epoch 65/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1036 - accuracy: 0.9581 - val_loss: 0.3118 - val_accuracy: 0.8872
# Epoch 66/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0969 - accuracy: 0.9584 - val_loss: 0.4253 - val_accuracy: 0.8818
# Epoch 67/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1074 - accuracy: 0.9575 - val_loss: 0.3356 - val_accuracy: 0.8967
# Epoch 68/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1095 - accuracy: 0.9551 - val_loss: 0.3753 - val_accuracy: 0.8845
# Epoch 69/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0999 - accuracy: 0.9616 - val_loss: 0.3116 - val_accuracy: 0.8927
# Epoch 70/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1056 - accuracy: 0.9569 - val_loss: 0.3881 - val_accuracy: 0.8804
# Epoch 71/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1033 - accuracy: 0.9580 - val_loss: 0.4194 - val_accuracy: 0.8927
# Epoch 72/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1104 - accuracy: 0.9550 - val_loss: 0.3267 - val_accuracy: 0.8940
# Epoch 73/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1021 - accuracy: 0.9569 - val_loss: 0.4485 - val_accuracy: 0.8995
# Epoch 74/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1075 - accuracy: 0.9575 - val_loss: 0.3702 - val_accuracy: 0.8832
# Epoch 75/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0974 - accuracy: 0.9598 - val_loss: 0.3505 - val_accuracy: 0.8913
# Epoch 76/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1025 - accuracy: 0.9592 - val_loss: 0.3890 - val_accuracy: 0.8927
# Epoch 77/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0897 - accuracy: 0.9619 - val_loss: 0.4106 - val_accuracy: 0.8913
# Epoch 78/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1020 - accuracy: 0.9609 - val_loss: 0.4316 - val_accuracy: 0.8859
# Epoch 79/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1010 - accuracy: 0.9577 - val_loss: 0.3462 - val_accuracy: 0.8913
# Epoch 80/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0977 - accuracy: 0.9609 - val_loss: 0.4517 - val_accuracy: 0.8927
# Epoch 81/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0959 - accuracy: 0.9622 - val_loss: 0.3356 - val_accuracy: 0.8981
# Epoch 82/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0931 - accuracy: 0.9615 - val_loss: 0.6075 - val_accuracy: 0.8573
# Epoch 83/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1076 - accuracy: 0.9586 - val_loss: 0.4190 - val_accuracy: 0.8804
# Epoch 84/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1041 - accuracy: 0.9596 - val_loss: 0.3610 - val_accuracy: 0.8913
# Epoch 85/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0988 - accuracy: 0.9592 - val_loss: 0.3720 - val_accuracy: 0.8967
# Epoch 86/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0997 - accuracy: 0.9593 - val_loss: 0.4099 - val_accuracy: 0.8859
# Epoch 87/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0966 - accuracy: 0.9589 - val_loss: 0.4803 - val_accuracy: 0.8696
# Epoch 88/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1033 - accuracy: 0.9599 - val_loss: 0.3713 - val_accuracy: 0.8791
# Epoch 89/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1006 - accuracy: 0.9616 - val_loss: 0.3402 - val_accuracy: 0.8913
# Epoch 90/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0964 - accuracy: 0.9604 - val_loss: 0.4820 - val_accuracy: 0.8832
# Epoch 91/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0905 - accuracy: 0.9639 - val_loss: 0.3540 - val_accuracy: 0.8940
# Epoch 92/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0876 - accuracy: 0.9622 - val_loss: 0.4507 - val_accuracy: 0.8804
# Epoch 93/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0938 - accuracy: 0.9606 - val_loss: 0.4115 - val_accuracy: 0.8927
# Epoch 94/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0953 - accuracy: 0.9628 - val_loss: 0.4210 - val_accuracy: 0.8940
# Epoch 95/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0916 - accuracy: 0.9640 - val_loss: 0.4597 - val_accuracy: 0.8832
# Epoch 96/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0925 - accuracy: 0.9639 - val_loss: 0.4325 - val_accuracy: 0.8818
# Epoch 97/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0927 - accuracy: 0.9613 - val_loss: 0.4598 - val_accuracy: 0.8886
# Epoch 98/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0921 - accuracy: 0.9631 - val_loss: 0.4083 - val_accuracy: 0.8981
# Epoch 99/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0929 - accuracy: 0.9624 - val_loss: 0.3592 - val_accuracy: 0.8845
# Epoch 100/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0918 - accuracy: 0.9628 - val_loss: 0.4233 - val_accuracy: 0.8859
# CPU times: user 2min 31s, sys: 30.1 s, total: 3min 1s
# Wall time: 2min 47s

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 30, 78)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 15, 78)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 15, 78)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 13, 32)        22496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 6, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 6, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1344)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                86080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 109,286
# Trainable params: 109,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions= model.predict(X_test_new)

# %%
y_pred = [np.argmax(x) for x in predictions]

# %%
y_test = y_test.reshape(-1)

# %%
(y_pred == y_test).mean()
# Out:
# 0.7407533084492705

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.67      0.65       496
#            1       0.63      0.71      0.67       471
#            2       0.62      0.97      0.75       420
#            3       0.89      0.70      0.78       491
#            4       0.79      0.48      0.60       532
#            5       1.00      0.95      0.97       537
#
#     accuracy                           0.74      2947
#    macro avg       0.76      0.75      0.74      2947
# weighted avg       0.77      0.74      0.74      2947

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras import callbacks
def build_model():
    model = Sequential()
    
    model.add(Convolution2D(32, (3, 3), activation='relu', input_shape=(1,32,80), data_format='channels_first'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))
    model.add(Convolution2D(32, (3, 3),activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25)) 
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    #model.add(LeakyReLU(alpha=0.03))
    model.add(Dropout(0.5))
    model.add(Dense(6, activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
    return model
reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.9)
keras_model = build_model()
keras_model.fit(X_train_new, Y_train_new, epochs=100, validation_split=0.1, batch_size=16, shuffle=True,
          callbacks=[reduce_lr])
predictions= keras_model.predict(X_test_new)
y_pred = [np.argmax(x) for x in predictions]
y_test = y_test.reshape(-1)
(y_pred == y_test).mean()
print(classification_report(y_test, y_pred))
y_score = predictions

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(Y_test_new[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
lw = 2
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

# Plot all ROC curves
plt.figure(figsize=(13,10))

colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'red', 'green', 'black'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve of fully connected neural network')
plt.legend(loc="lower right")
plt.show()
# Out:
# Epoch 1/100
# 414/414 [==============================] - 2s 4ms/step - loss: 1.1126 - accuracy: 0.5014 - val_loss: 0.7070 - val_accuracy: 0.6087 - lr: 0.0010
# Epoch 2/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.7068 - accuracy: 0.6681 - val_loss: 0.6320 - val_accuracy: 0.6685 - lr: 0.0010
# Epoch 3/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.6354 - accuracy: 0.7006 - val_loss: 0.6596 - val_accuracy: 0.6902 - lr: 0.0010
# Epoch 4/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.5947 - accuracy: 0.7338 - val_loss: 0.6448 - val_accuracy: 0.6861 - lr: 0.0010
# Epoch 5/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.5563 - accuracy: 0.7495 - val_loss: 0.5174 - val_accuracy: 0.7826 - lr: 0.0010
# Epoch 6/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.5165 - accuracy: 0.7842 - val_loss: 0.5364 - val_accuracy: 0.7758 - lr: 0.0010
# Epoch 7/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.4790 - accuracy: 0.8002 - val_loss: 0.5196 - val_accuracy: 0.7894 - lr: 0.0010
# Epoch 8/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.4446 - accuracy: 0.8197 - val_loss: 0.4457 - val_accuracy: 0.8234 - lr: 0.0010
# Epoch 9/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.4002 - accuracy: 0.8401 - val_loss: 0.4246 - val_accuracy: 0.8111 - lr: 0.0010
# Epoch 10/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.3729 - accuracy: 0.8543 - val_loss: 0.4806 - val_accuracy: 0.8111 - lr: 0.0010
# Epoch 11/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.3458 - accuracy: 0.8656 - val_loss: 0.4360 - val_accuracy: 0.8152 - lr: 0.0010
# Epoch 12/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.3369 - accuracy: 0.8711 - val_loss: 0.5159 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 13/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.3073 - accuracy: 0.8810 - val_loss: 0.3995 - val_accuracy: 0.8370 - lr: 0.0010
# Epoch 14/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2843 - accuracy: 0.8900 - val_loss: 0.3831 - val_accuracy: 0.8451 - lr: 0.0010
# Epoch 15/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2641 - accuracy: 0.9030 - val_loss: 0.3771 - val_accuracy: 0.8478 - lr: 0.0010
# Epoch 16/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2554 - accuracy: 0.8977 - val_loss: 0.4416 - val_accuracy: 0.8342 - lr: 0.0010
# Epoch 17/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2529 - accuracy: 0.9002 - val_loss: 0.3890 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 18/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2288 - accuracy: 0.9098 - val_loss: 0.3381 - val_accuracy: 0.8560 - lr: 0.0010
# Epoch 19/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2273 - accuracy: 0.9104 - val_loss: 0.3634 - val_accuracy: 0.8628 - lr: 0.0010
# Epoch 20/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2193 - accuracy: 0.9175 - val_loss: 0.4121 - val_accuracy: 0.8356 - lr: 0.0010
# Epoch 21/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.2256 - accuracy: 0.9122 - val_loss: 0.3493 - val_accuracy: 0.8655 - lr: 0.0010
# Epoch 22/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1944 - accuracy: 0.9256 - val_loss: 0.3355 - val_accuracy: 0.8777 - lr: 0.0010
# Epoch 23/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1977 - accuracy: 0.9197 - val_loss: 0.3679 - val_accuracy: 0.8587 - lr: 0.0010
# Epoch 24/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1816 - accuracy: 0.9241 - val_loss: 0.3982 - val_accuracy: 0.8505 - lr: 0.0010
# Epoch 25/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1970 - accuracy: 0.9234 - val_loss: 0.3240 - val_accuracy: 0.8791 - lr: 0.0010
# Epoch 26/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1753 - accuracy: 0.9332 - val_loss: 0.3199 - val_accuracy: 0.8818 - lr: 0.0010
# Epoch 27/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1701 - accuracy: 0.9296 - val_loss: 0.2997 - val_accuracy: 0.8872 - lr: 0.0010
# Epoch 28/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1696 - accuracy: 0.9339 - val_loss: 0.3232 - val_accuracy: 0.8845 - lr: 0.0010
# Epoch 29/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1588 - accuracy: 0.9367 - val_loss: 0.2693 - val_accuracy: 0.8967 - lr: 0.0010
# Epoch 30/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1641 - accuracy: 0.9333 - val_loss: 0.3204 - val_accuracy: 0.8804 - lr: 0.0010
# Epoch 31/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1718 - accuracy: 0.9321 - val_loss: 0.3425 - val_accuracy: 0.8682 - lr: 0.0010
# Epoch 32/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1453 - accuracy: 0.9417 - val_loss: 0.3094 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 33/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1552 - accuracy: 0.9403 - val_loss: 0.3159 - val_accuracy: 0.8709 - lr: 0.0010
# Epoch 34/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1450 - accuracy: 0.9436 - val_loss: 0.4206 - val_accuracy: 0.8628 - lr: 0.0010
# Epoch 35/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1494 - accuracy: 0.9433 - val_loss: 0.4178 - val_accuracy: 0.8519 - lr: 0.0010
# Epoch 36/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1517 - accuracy: 0.9439 - val_loss: 0.3628 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 37/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1455 - accuracy: 0.9421 - val_loss: 0.4673 - val_accuracy: 0.8451 - lr: 0.0010
# Epoch 38/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1416 - accuracy: 0.9436 - val_loss: 0.3366 - val_accuracy: 0.8764 - lr: 0.0010
# Epoch 39/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1363 - accuracy: 0.9420 - val_loss: 0.3812 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 40/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1317 - accuracy: 0.9479 - val_loss: 0.4099 - val_accuracy: 0.8438 - lr: 9.0000e-04
# Epoch 41/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1315 - accuracy: 0.9456 - val_loss: 0.4137 - val_accuracy: 0.8546 - lr: 9.0000e-04
# Epoch 42/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1249 - accuracy: 0.9501 - val_loss: 0.3441 - val_accuracy: 0.8954 - lr: 9.0000e-04
# Epoch 43/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1309 - accuracy: 0.9466 - val_loss: 0.3713 - val_accuracy: 0.8777 - lr: 9.0000e-04
# Epoch 44/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1240 - accuracy: 0.9486 - val_loss: 0.4423 - val_accuracy: 0.8533 - lr: 9.0000e-04
# Epoch 45/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1295 - accuracy: 0.9450 - val_loss: 0.3360 - val_accuracy: 0.8736 - lr: 9.0000e-04
# Epoch 46/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1240 - accuracy: 0.9486 - val_loss: 0.3692 - val_accuracy: 0.8845 - lr: 9.0000e-04
# Epoch 47/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1223 - accuracy: 0.9509 - val_loss: 0.4751 - val_accuracy: 0.8614 - lr: 9.0000e-04
# Epoch 48/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1222 - accuracy: 0.9507 - val_loss: 0.3499 - val_accuracy: 0.8668 - lr: 9.0000e-04
# Epoch 49/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1143 - accuracy: 0.9541 - val_loss: 0.4470 - val_accuracy: 0.8655 - lr: 9.0000e-04
# Epoch 50/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1164 - accuracy: 0.9501 - val_loss: 0.4939 - val_accuracy: 0.8723 - lr: 8.1000e-04
# Epoch 51/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1201 - accuracy: 0.9536 - val_loss: 0.4073 - val_accuracy: 0.8587 - lr: 8.1000e-04
# Epoch 52/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1133 - accuracy: 0.9519 - val_loss: 0.4112 - val_accuracy: 0.8668 - lr: 8.1000e-04
# Epoch 53/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1135 - accuracy: 0.9536 - val_loss: 0.3758 - val_accuracy: 0.8804 - lr: 8.1000e-04
# Epoch 54/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1075 - accuracy: 0.9578 - val_loss: 0.4409 - val_accuracy: 0.8709 - lr: 8.1000e-04
# Epoch 55/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1064 - accuracy: 0.9565 - val_loss: 0.3320 - val_accuracy: 0.8899 - lr: 8.1000e-04
# Epoch 56/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1185 - accuracy: 0.9531 - val_loss: 0.3965 - val_accuracy: 0.8628 - lr: 8.1000e-04
# Epoch 57/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1162 - accuracy: 0.9525 - val_loss: 0.4318 - val_accuracy: 0.8777 - lr: 8.1000e-04
# Epoch 58/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1102 - accuracy: 0.9533 - val_loss: 0.3769 - val_accuracy: 0.8791 - lr: 8.1000e-04
# Epoch 59/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1191 - accuracy: 0.9528 - val_loss: 0.3906 - val_accuracy: 0.8804 - lr: 8.1000e-04
# Epoch 60/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1042 - accuracy: 0.9572 - val_loss: 0.3378 - val_accuracy: 0.8899 - lr: 7.2900e-04
# Epoch 61/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1100 - accuracy: 0.9536 - val_loss: 0.4959 - val_accuracy: 0.8668 - lr: 7.2900e-04
# Epoch 62/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1093 - accuracy: 0.9541 - val_loss: 0.4971 - val_accuracy: 0.8587 - lr: 7.2900e-04
# Epoch 63/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1051 - accuracy: 0.9586 - val_loss: 0.3737 - val_accuracy: 0.8886 - lr: 7.2900e-04
# Epoch 64/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1083 - accuracy: 0.9559 - val_loss: 0.4651 - val_accuracy: 0.8601 - lr: 7.2900e-04
# Epoch 65/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0980 - accuracy: 0.9593 - val_loss: 0.4197 - val_accuracy: 0.8777 - lr: 7.2900e-04
# Epoch 66/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1067 - accuracy: 0.9550 - val_loss: 0.4314 - val_accuracy: 0.8859 - lr: 7.2900e-04
# Epoch 67/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1082 - accuracy: 0.9560 - val_loss: 0.3731 - val_accuracy: 0.8791 - lr: 7.2900e-04
# Epoch 68/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1076 - accuracy: 0.9554 - val_loss: 0.4865 - val_accuracy: 0.8723 - lr: 7.2900e-04
# Epoch 69/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0975 - accuracy: 0.9586 - val_loss: 0.4397 - val_accuracy: 0.8709 - lr: 7.2900e-04
# Epoch 70/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0920 - accuracy: 0.9580 - val_loss: 0.4330 - val_accuracy: 0.8872 - lr: 6.5610e-04
# Epoch 71/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0944 - accuracy: 0.9590 - val_loss: 0.4693 - val_accuracy: 0.8682 - lr: 6.5610e-04
# Epoch 72/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1021 - accuracy: 0.9556 - val_loss: 0.4535 - val_accuracy: 0.8736 - lr: 6.5610e-04
# Epoch 73/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0974 - accuracy: 0.9604 - val_loss: 0.3885 - val_accuracy: 0.8859 - lr: 6.5610e-04
# Epoch 74/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1012 - accuracy: 0.9595 - val_loss: 0.4821 - val_accuracy: 0.8940 - lr: 6.5610e-04
# Epoch 75/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0971 - accuracy: 0.9607 - val_loss: 0.4633 - val_accuracy: 0.8709 - lr: 6.5610e-04
# Epoch 76/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.1006 - accuracy: 0.9577 - val_loss: 0.5871 - val_accuracy: 0.8750 - lr: 6.5610e-04
# Epoch 77/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0959 - accuracy: 0.9598 - val_loss: 0.5610 - val_accuracy: 0.8709 - lr: 6.5610e-04
# Epoch 78/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0871 - accuracy: 0.9604 - val_loss: 0.4239 - val_accuracy: 0.8777 - lr: 6.5610e-04
# Epoch 79/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0924 - accuracy: 0.9610 - val_loss: 0.4417 - val_accuracy: 0.8764 - lr: 6.5610e-04
# Epoch 80/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0898 - accuracy: 0.9634 - val_loss: 0.4346 - val_accuracy: 0.8899 - lr: 5.9049e-04
# Epoch 81/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0887 - accuracy: 0.9624 - val_loss: 0.5217 - val_accuracy: 0.8859 - lr: 5.9049e-04
# Epoch 82/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0890 - accuracy: 0.9592 - val_loss: 0.4895 - val_accuracy: 0.8696 - lr: 5.9049e-04
# Epoch 83/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0882 - accuracy: 0.9654 - val_loss: 0.4806 - val_accuracy: 0.8804 - lr: 5.9049e-04
# Epoch 84/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0947 - accuracy: 0.9619 - val_loss: 0.3649 - val_accuracy: 0.8913 - lr: 5.9049e-04
# Epoch 85/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0970 - accuracy: 0.9590 - val_loss: 0.4453 - val_accuracy: 0.8913 - lr: 5.9049e-04
# Epoch 86/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0880 - accuracy: 0.9637 - val_loss: 0.5615 - val_accuracy: 0.8804 - lr: 5.9049e-04
# Epoch 87/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0899 - accuracy: 0.9637 - val_loss: 0.4748 - val_accuracy: 0.8832 - lr: 5.9049e-04
# Epoch 88/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0890 - accuracy: 0.9639 - val_loss: 0.4131 - val_accuracy: 0.8832 - lr: 5.9049e-04
# Epoch 89/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0889 - accuracy: 0.9619 - val_loss: 0.4957 - val_accuracy: 0.8859 - lr: 5.9049e-04
# Epoch 90/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0880 - accuracy: 0.9640 - val_loss: 0.5612 - val_accuracy: 0.8668 - lr: 5.3144e-04
# Epoch 91/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0805 - accuracy: 0.9657 - val_loss: 0.5297 - val_accuracy: 0.8845 - lr: 5.3144e-04
# Epoch 92/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0860 - accuracy: 0.9631 - val_loss: 0.4797 - val_accuracy: 0.8899 - lr: 5.3144e-04
# Epoch 93/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0880 - accuracy: 0.9651 - val_loss: 0.5226 - val_accuracy: 0.8832 - lr: 5.3144e-04
# Epoch 94/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0845 - accuracy: 0.9634 - val_loss: 0.4933 - val_accuracy: 0.8913 - lr: 5.3144e-04
# Epoch 95/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0821 - accuracy: 0.9636 - val_loss: 0.5621 - val_accuracy: 0.8777 - lr: 5.3144e-04
# Epoch 96/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0849 - accuracy: 0.9636 - val_loss: 0.6705 - val_accuracy: 0.8492 - lr: 5.3144e-04
# Epoch 97/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0815 - accuracy: 0.9649 - val_loss: 0.4533 - val_accuracy: 0.8859 - lr: 5.3144e-04
# Epoch 98/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0841 - accuracy: 0.9658 - val_loss: 0.4737 - val_accuracy: 0.8913 - lr: 5.3144e-04
# Epoch 99/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0807 - accuracy: 0.9690 - val_loss: 0.5972 - val_accuracy: 0.8777 - lr: 5.3144e-04
# Epoch 100/100
# 414/414 [==============================] - 2s 4ms/step - loss: 0.0818 - accuracy: 0.9642 - val_loss: 0.4858 - val_accuracy: 0.8845 - lr: 4.7830e-04
#               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60       496
#            1       0.70      0.77      0.73       471
#            2       0.68      0.95      0.79       420
#            3       0.92      0.62      0.74       491
#            4       0.83      0.38      0.53       532
#            5       1.00      0.97      0.99       537
#
#     accuracy                           0.73      2947
#    macro avg       0.77      0.74      0.73      2947
# weighted avg       0.78      0.73      0.73      2947
