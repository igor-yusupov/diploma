# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import pylab
import warnings as w
import os

# %matplotlib inline

# %%
import matplotlib
matplotlib.rcParams.update({'font.size':14})
plt.rcParams['figure.figsize'] = (10,8)
plt.rcParams['font.size'] = 14
plt.rcParams['image.cmap'] = 'plasma'
plt.rcParams['axes.linewidth'] = 2

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# !unzip UCI\ HAR\ Dataset.zip
# Out:
# --2020-05-31 11:40:13--  https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60999314 (58M) [application/x-httpd-php]
# Saving to: ‘UCI HAR Dataset.zip’
#
# UCI HAR Dataset.zip 100%[===================>]  58.17M  16.4MB/s    in 4.5s
#
# 2020-05-31 11:40:18 (12.8 MB/s) - ‘UCI HAR Dataset.zip’ saved [60999314/60999314]
#
# Archive:  UCI HAR Dataset.zip
#    creating: UCI HAR Dataset/
#   inflating: UCI HAR Dataset/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/UCI HAR Dataset/
#   inflating: __MACOSX/UCI HAR Dataset/._.DS_Store
#   inflating: UCI HAR Dataset/activity_labels.txt
#   inflating: __MACOSX/UCI HAR Dataset/._activity_labels.txt
#   inflating: UCI HAR Dataset/features.txt
#   inflating: __MACOSX/UCI HAR Dataset/._features.txt
#   inflating: UCI HAR Dataset/features_info.txt
#   inflating: __MACOSX/UCI HAR Dataset/._features_info.txt
#   inflating: UCI HAR Dataset/README.txt
#   inflating: __MACOSX/UCI HAR Dataset/._README.txt
#    creating: UCI HAR Dataset/test/
#    creating: UCI HAR Dataset/test/Inertial Signals/
#   inflating: UCI HAR Dataset/test/Inertial Signals/body_acc_x_test.txt
#    creating: __MACOSX/UCI HAR Dataset/test/
#    creating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/
#   inflating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/._body_acc_x_test.txt
#   inflating: UCI HAR Dataset/test/Inertial Signals/body_acc_y_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/._body_acc_y_test.txt
#   inflating: UCI HAR Dataset/test/Inertial Signals/body_acc_z_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/._body_acc_z_test.txt
#   inflating: UCI HAR Dataset/test/Inertial Signals/body_gyro_x_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/._body_gyro_x_test.txt
#   inflating: UCI HAR Dataset/test/Inertial Signals/body_gyro_y_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/._body_gyro_y_test.txt
#   inflating: UCI HAR Dataset/test/Inertial Signals/body_gyro_z_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/._body_gyro_z_test.txt
#   inflating: UCI HAR Dataset/test/Inertial Signals/total_acc_x_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/._total_acc_x_test.txt
#   inflating: UCI HAR Dataset/test/Inertial Signals/total_acc_y_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/._total_acc_y_test.txt
#   inflating: UCI HAR Dataset/test/Inertial Signals/total_acc_z_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/._total_acc_z_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/._Inertial Signals
#   inflating: UCI HAR Dataset/test/subject_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/._subject_test.txt
#   inflating: UCI HAR Dataset/test/X_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/._X_test.txt
#   inflating: UCI HAR Dataset/test/y_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/test/._y_test.txt
#   inflating: __MACOSX/UCI HAR Dataset/._test
#    creating: UCI HAR Dataset/train/
#    creating: UCI HAR Dataset/train/Inertial Signals/
#   inflating: UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt
#    creating: __MACOSX/UCI HAR Dataset/train/
#    creating: __MACOSX/UCI HAR Dataset/train/Inertial Signals/
#   inflating: __MACOSX/UCI HAR Dataset/train/Inertial Signals/._body_acc_x_train.txt
#   inflating: UCI HAR Dataset/train/Inertial Signals/body_acc_y_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/train/Inertial Signals/._body_acc_y_train.txt
#   inflating: UCI HAR Dataset/train/Inertial Signals/body_acc_z_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/train/Inertial Signals/._body_acc_z_train.txt
#   inflating: UCI HAR Dataset/train/Inertial Signals/body_gyro_x_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/train/Inertial Signals/._body_gyro_x_train.txt
#   inflating: UCI HAR Dataset/train/Inertial Signals/body_gyro_y_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/train/Inertial Signals/._body_gyro_y_train.txt
#   inflating: UCI HAR Dataset/train/Inertial Signals/body_gyro_z_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/train/Inertial Signals/._body_gyro_z_train.txt
#   inflating: UCI HAR Dataset/train/Inertial Signals/total_acc_x_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/train/Inertial Signals/._total_acc_x_train.txt
#   inflating: UCI HAR Dataset/train/Inertial Signals/total_acc_y_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/train/Inertial Signals/._total_acc_y_train.txt
#   inflating: UCI HAR Dataset/train/Inertial Signals/total_acc_z_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/train/Inertial Signals/._total_acc_z_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/train/._Inertial Signals
#   inflating: UCI HAR Dataset/train/subject_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/train/._subject_train.txt
#   inflating: UCI HAR Dataset/train/X_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/train/._X_train.txt
#   inflating: UCI HAR Dataset/train/y_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/train/._y_train.txt
#   inflating: __MACOSX/UCI HAR Dataset/._train
#   inflating: __MACOSX/._UCI HAR Dataset

# %%
class SSA(object):
    
    __supported_types = (pd.Series, np.ndarray, list)
    
    def __init__(self, tseries, L, save_mem=True):
        """
        Decomposes the given time series with a singular-spectrum analysis. Assumes the values of the time series are
        recorded at equal intervals.
        
        Parameters
        ----------
        tseries : The original time series, in the form of a Pandas Series, NumPy array or list. 
        L : The window length. Must be an integer 2 <= L <= N/2, where N is the length of the time series.
        save_mem : Conserve memory by not retaining the elementary matrices. Recommended for long time series with
            thousands of values. Defaults to True.
        
        Note: Even if an NumPy array or list is used for the initial time series, all time series returned will be
        in the form of a Pandas Series or DataFrame object.
        """
        
        # Tedious type-checking for the initial time series
        if not isinstance(tseries, self.__supported_types):
            raise TypeError("Unsupported time series object. Try Pandas Series, NumPy array or list.")
        
        # Checks to save us from ourselves
        self.N = len(tseries)
        if not 2 <= L <= self.N/2:
            raise ValueError("The window length must be in the interval [2, N/2].")
        
        self.L = L
        self.orig_TS = pd.Series(tseries)
        self.K = self.N - self.L + 1
        
        # Embed the time series in a trajectory matrix
        self.X = np.array([self.orig_TS.values[i:L+i] for i in range(0, self.K)]).T
        
        # Decompose the trajectory matrix
        self.U, self.Sigma, VT = np.linalg.svd(self.X)
        self.d = np.linalg.matrix_rank(self.X)
        
        self.TS_comps = np.zeros((self.N, self.d))
        
        if not save_mem:
            # Construct and save all the elementary matrices
            self.X_elem = np.array([ self.Sigma[i]*np.outer(self.U[:,i], VT[i,:]) for i in range(self.d) ])

            # Diagonally average the elementary matrices, store them as columns in array.           
            for i in range(self.d):
                X_rev = self.X_elem[i, ::-1]
                self.TS_comps[:,i] = [X_rev.diagonal(j).mean() for j in range(-X_rev.shape[0]+1, X_rev.shape[1])]
            
            self.V = VT.T
        else:
            # Reconstruct the elementary matrices without storing them
            for i in range(self.d):
                X_elem = self.Sigma[i]*np.outer(self.U[:,i], VT[i,:])
                X_rev = X_elem[::-1]
                self.TS_comps[:,i] = [X_rev.diagonal(j).mean() for j in range(-X_rev.shape[0]+1, X_rev.shape[1])]
            
            self.X_elem = "Re-run with save_mem=False to retain the elementary matrices."
            
            # The V array may also be very large under these circumstances, so we won't keep it.
            self.V = "Re-run with save_mem=False to retain the V matrix."
        
        # Calculate the w-correlation matrix.
        self.calc_wcorr()
            
    def components_to_df(self, n=0):
        """
        Returns all the time series components in a single Pandas DataFrame object.
        """
        if n > 0:
            n = min(n, self.d)
        else:
            n = self.d
        
        # Create list of columns - call them F0, F1, F2, ...
        cols = ["F{}".format(i) for i in range(n)]
        return pd.DataFrame(self.TS_comps[:, :n], columns=cols, index=self.orig_TS.index)
            
    
    def reconstruct(self, indices):
        """
        Reconstructs the time series from its elementary components, using the given indices. Returns a Pandas Series
        object with the reconstructed time series.
        
        Parameters
        ----------
        indices: An integer, list of integers or slice(n,m) object, representing the elementary components to sum.
        """
        if isinstance(indices, int): indices = [indices]
        
        ts_vals = self.TS_comps[:,indices].sum(axis=1)
        return pd.Series(ts_vals, index=self.orig_TS.index)
    
    def calc_wcorr(self):
        """
        Calculates the w-correlation matrix for the time series.
        """
             
        # Calculate the weights
        w = np.array(list(np.arange(self.L)+1) + [self.L]*(self.K-self.L-1) + list(np.arange(self.L)+1)[::-1])
        
        def w_inner(F_i, F_j):
            return w.dot(F_i*F_j)
        
        # Calculated weighted norms, ||F_i||_w, then invert.
        F_wnorms = np.array([w_inner(self.TS_comps[:,i], self.TS_comps[:,i]) for i in range(self.d)])
        F_wnorms = F_wnorms**-0.5
        
        # Calculate Wcorr.
        self.Wcorr = np.identity(self.d)
        for i in range(self.d):
            for j in range(i+1,self.d):
                self.Wcorr[i,j] = abs(w_inner(self.TS_comps[:,i], self.TS_comps[:,j]) * F_wnorms[i] * F_wnorms[j])
                self.Wcorr[j,i] = self.Wcorr[i,j]
    
    def plot_wcorr(self, min=None, max=None):
        """
        Plots the w-correlation matrix for the decomposed time series.
        """
        if min is None:
            min = 0
        if max is None:
            max = self.d
        
        if self.Wcorr is None:
            self.calc_wcorr()
        
        ax = plt.imshow(self.Wcorr)
        plt.xlabel(r"$\tilde{F}_i$")
        plt.ylabel(r"$\tilde{F}_j$")
        plt.colorbar(ax.colorbar, fraction=0.045)
        ax.colorbar.set_label("$W_{i,j}$")
        plt.clim(0,1)
        
        # For plotting purposes:
        if max == self.d:
            max_rnge = self.d-1
        else:
            max_rnge = max
        
        plt.xlim(min-0.5, max_rnge+0.5)
        plt.ylim(max_rnge+0.5, min-0.5)

# %%
X_train_with_engineered_features = np.genfromtxt(os.path.join("UCI HAR Dataset", "train", "X_train.txt"))
y_train = np.genfromtxt(os.path.join("UCI HAR Dataset", "train", "y_train.txt"))

y_train_list = list(y_train)
X_unique = np.array([X_train_with_engineered_features[y_train_list.index(l)]
                             for l in sorted(list(set(y_train)))])

legend_labels = ["WALKING", "WALKING.UP", "WALKING.DOWN", "SITTING", "STANDING", "LAYING"]
colors_list = ['red', 'blue', 'green', 'orange', 'cyan', 'magenta']
mapped_colors = [colors_list[int(i)-1] for i in y_train]

from sklearn.decomposition import PCA
pca = PCA()

X_train_pca = pca.fit_transform(X_train_with_engineered_features)

plt.figure(figsize=(15,10))
pylab.scatter(X_train_pca[:, 0], X_train_pca[:, 1],
             c=mapped_colors)
plt.grid()
for idx, x in enumerate(pca.transform(X_unique)):
    plt.scatter(x[0], 
                x[1], 
                c=colors_list[idx], 
                label=legend_labels[idx])
plt.xlabel('First principal component')
plt.ylabel('Second principal component')
plt.legend()

# %%
# Useful Constants

# Those are separate normalised input features for the neural network
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

# Output classes to learn how to classify
LABELS = [
    "WALKING", 
    "WALKING_UPSTAIRS", 
    "WALKING_DOWNSTAIRS", 
    "SITTING", 
    "STANDING", 
    "LAYING"
]

DATA_PATH = "./"

DATASET_PATH = DATA_PATH + "UCI HAR Dataset/"
print("\n" + "Dataset is now located at: " + DATASET_PATH)

TRAIN = "train/"
TEST = "test/"


# Load "X" (the neural network's training and testing inputs)

def load_X(X_signals_paths):
    X_signals = []
    
    for signal_type_path in X_signals_paths:
        file = open(signal_type_path, 'r')
        # Read dataset from disk, dealing with text files' syntax
        X_signals.append(
            [np.array(serie, dtype=np.float32) for serie in [
                row.replace('  ', ' ').strip().split(' ') for row in file
            ]]
        )
        file.close()
    
    return np.transpose(np.array(X_signals), (1, 2, 0))

X_train_signals_paths = [
    os.path.join(*[DATASET_PATH, TRAIN, "Inertial Signals/", signal+"train.txt"]) for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    os.path.join(*[DATASET_PATH, TEST, "Inertial Signals/", signal+"test.txt"]) for signal in INPUT_SIGNAL_TYPES
]

X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)


# Load "y" (the neural network's training and testing outputs)

def load_y(y_path):
    file = open(y_path, 'r')
    # Read dataset from disk, dealing with text file's syntax
    y_ = np.array(
        [elem for elem in [
            row.replace('  ', ' ').strip().split(' ') for row in file
        ]], 
        dtype=np.int32
    )
    file.close()
    
    # Substract 1 to each output class for friendly 0-based indexing 
    return y_ - 1

y_train_path = os.path.join(DATASET_PATH, TRAIN, "y_train.txt")
y_test_path = os.path.join(DATASET_PATH, TEST, "y_test.txt")

y_train = load_y(y_train_path)
y_test = load_y(y_test_path)
# Out:
# Dataset is now located at: ./UCI HAR Dataset/

# %%
# Input Data 

training_data_count = len(X_train)  # 7352 training series (with 50% overlap between each serie)
test_data_count = len(X_test)  # 2947 testing series
n_steps = len(X_train[0])  # 128 timesteps per series
n_input = len(X_train[0][0])  # 9 input parameters per timestep


# LSTM Neural Network's internal structure

n_hidden = 32 # Hidden layer num of features
n_classes = 6 # Total classes (should go up, or should go down)


# Some debugging info

print("Some useful info to get an insight on dataset's shape and normalisation:")
print("(X shape, y shape, every X's mean, every X's standard deviation)")
print(X_test.shape, y_test.shape, np.mean(X_test), np.std(X_test))
print("The dataset is therefore properly normalised, as expected, but not yet one-hot encoded.")
# Out:
# Some useful info to get an insight on dataset's shape and normalisation:
# (X shape, y shape, every X's mean, every X's standard deviation)
# (2947, 128, 9) (2947, 1) 0.09913992 0.39567086
# The dataset is therefore properly normalised, as expected, but not yet one-hot encoded.

# %%
from tqdm.notebook import tqdm

# %%
# %%time
X_train_new = np.array([])
for x in tqdm(X_train):
    x = x.reshape(9, 128)
    a = np.array([])
    for t in x:
        F_ssa_L5 = SSA(t, 5)
        series = {}
        for i in range(5):
            for j in range(5):
                if F_ssa_L5.Wcorr[i][j] > 0.3 and i < j:
                    if i in series:
                        series[i].append(j)
                    else:
                        series[i] = [j]
                        series[i].append(i)
        slices = [value for value in series.values()]
        for s in slices:
            if len(a) != 0:
                a = np.append(a, F_ssa_L5.reconstruct(s).to_numpy().reshape(1, 128), axis=0)
            else:
                a = F_ssa_L5.reconstruct(s).to_numpy().reshape(1, 128)
    if len(X_train_new) != 0:
        X_train_new = np.append(X_train_new, a[:14].reshape(1,14,128), axis=0)
    else:
        X_train_new = a[:14].reshape(1,14,128)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7352.0), HTML(value='')))
# CPU times: user 15min 26s, sys: 11min 7s, total: 26min 33s
# Wall time: 13min 54s

# %%
# %%time
X_test_new = np.array([])
for x in tqdm(X_test):
    x = x.reshape(9, 128)
    a = np.array([])
    for t in x:
        F_ssa_L5 = SSA(t, 5)
        series = {}
        for i in range(5):
            for j in range(5):
                if F_ssa_L5.Wcorr[i][j] > 0.3 and i < j:
                    if i in series:
                        series[i].append(j)
                    else:
                        series[i] = [j]
                        series[i].append(i)
        slices = [value for value in series.values()]
        for s in slices:
            if len(a) != 0:
                a = np.append(a, F_ssa_L5.reconstruct(s).to_numpy().reshape(1, 128), axis=0)
            else:
                a = F_ssa_L5.reconstruct(s).to_numpy().reshape(1, 128)
    if len(X_test_new) != 0:
        X_test_new = np.append(X_test_new, a[:14].reshape(1,14,128), axis=0)
    else:
        X_test_new = a[:14].reshape(1,14,128)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2947.0), HTML(value='')))
# CPU times: user 5min 55s, sys: 4min 13s, total: 10min 8s
# Wall time: 5min 20s

# %%
# %%time
X_train_new_sigma = np.array([])
for x in tqdm(X_train):
    x = x.reshape(9, 128)
    a = np.array([])
    for t in x:
        F_ssa_L10 = SSA(t, 17)
        if len(a) != 0:
            a = np.append(a, F_ssa_L10.Sigma, axis=0)
        else:
            a = F_ssa_L10.Sigma
    if len(X_train_new_sigma) != 0:
        X_train_new_sigma = np.append(X_train_new_sigma, a, axis=0)
    else:
        X_train_new_sigma = a
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7352.0), HTML(value='')))
# CPU times: user 39min 46s, sys: 27min 37s, total: 1h 7min 23s
# Wall time: 34min 43s

# %%
# %%time
X_test_new_sigma = np.array([])
for x in tqdm(X_test):
    x = x.reshape(9, 128)
    a = np.array([])
    for t in x:
        F_ssa_L10 = SSA(t, 17)
        if len(a) != 0:
            a = np.append(a, F_ssa_L10.Sigma, axis=0)
        else:
            a = F_ssa_L10.Sigma
    if len(X_test_new_sigma) != 0:
        X_test_new_sigma = np.append(X_test_new_sigma, a, axis=0)
    else:
        X_test_new_sigma = a
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2947.0), HTML(value='')))
# CPU times: user 15min 39s, sys: 10min 53s, total: 26min 33s
# Wall time: 13min 41s

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, concatenate
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Input
from keras.utils import np_utils

# %%
X_train = X_train.reshape(X_train.shape[0], 1, 32, -1)
X_train = X_train.astype('float32')
X_train /= np.amax(X_train)
X_train_new = X_train_new.reshape(X_train_new.shape[0], 1, 32, -1)
X_train_new = X_train_new.astype('float32')
X_train_new /= np.amax(X_train_new)
X_train_sigma = X_train_new_sigma.reshape(7352, -1)
X_train_sigma = X_train_sigma.astype('float32')
X_train_sigma /= np.amax(X_train_sigma)
y_train_new = y_train.reshape(-1)
Y_train_new = np_utils.to_categorical(y_train_new, 6)


X_test_new = X_test_new.reshape(X_test_new.shape[0], 1, 32, -1)
X_test_new = X_test_new.astype('float32')
X_test_new /= np.amax(X_test_new)
X_test = X_test.reshape(X_test.shape[0], 1, 32, -1)
X_test = X_test.astype('float32')
X_test /= np.amax(X_test)
X_test_sigma = X_test_new_sigma.reshape(X_test.shape[0], -1)
X_test_sigma = X_test_sigma.astype('float32')
X_test_sigma /= np.amax(X_test_sigma)
Y_test_new = np_utils.to_categorical(y_test.reshape(-1), 6)

# %%
x = Input(shape=(1, 32, 36), dtype='float32', name='x')
x_new = Input(shape=(1, 32, 56), dtype='float32', name='x_new')
x_sigma = Input(shape=(153), dtype='float32', name='x_sigma')

x1 = Convolution2D(32, (3, 3), activation='relu', input_shape=(1, 32, 36), data_format='channels_first')(x)
x2 = MaxPooling2D(pool_size=(2,2))(x1)
x3 = Dropout(0.25)(x2)
x4 = Convolution2D(32, (3, 3),activation='relu')(x3)
x5 = MaxPooling2D(pool_size=(2,2))(x4)
x6 = Dropout(0.25)(x5)
x7 = Flatten()(x6)
x8 = Dense(64, activation='relu')(x7)
x9 = Dropout(0.25)(x8)

x_new1 = Convolution2D(32, (3, 3), activation='relu', input_shape=(1, 32, 56), data_format='channels_first')(x_new)
x_new2 = MaxPooling2D(pool_size=(2,2))(x_new1)
x_new3 = Dropout(0.6)(x_new2)
x_new4 = Convolution2D(32, (3, 3),activation='relu')(x_new3)
x_new5 = MaxPooling2D(pool_size=(2,2))(x_new4)
x_new6 = Dropout(0.6)(x_new5)
x_new7 = Flatten()(x_new6)
x_new8 = Dense(64, activation='relu')(x_new7)
x_new9 = Dropout(0.6)(x_new8)

x_sigma1 = Dense(100, activation='relu')(x_sigma)
x_sigma2 = Dropout(0.25)(x_sigma1)
x_sigma3 = Dense(100, activation='relu')(x_sigma2)
x_sigma4 = Dropout(0.25)(x_sigma3)
x_sigma5 = Dense(100, activation='relu')(x_sigma4)
x_sigma6 = Dropout(0.25)(x_sigma5)
x_sigma7 = Dense(100, activation='relu')(x_sigma6)
x_sigma8 = Dropout(0.25)(x_sigma7)
x_sigma9 = Dense(100, activation='relu')(x_sigma8)
x_sigma10 = Dropout(0.25)(x_sigma8)


concatenated = concatenate([x9, x_sigma], axis=-1)
c = Dense(64, activation='relu')(concatenated)
answer = Dense(6, activation='softmax')(c)
model = Model([x, x_sigma], answer)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
history = model.fit({'x': X_train, 'x_new': X_train_new, 'x_sigma': X_train_sigma}, Y_train_new, epochs=200, validation_split=0.1, batch_size=256,shuffle=True)
# Out:
# Epoch 1/200
# 26/26 [==============================] - 0s 16ms/step - loss: 1.4603 - accuracy: 0.4167 - val_loss: 0.8683 - val_accuracy: 0.5394
# Epoch 2/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.7590 - accuracy: 0.6378 - val_loss: 0.5839 - val_accuracy: 0.8030
# Epoch 3/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.5910 - accuracy: 0.7322 - val_loss: 0.4628 - val_accuracy: 0.8397
# Epoch 4/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.4805 - accuracy: 0.8071 - val_loss: 0.4084 - val_accuracy: 0.8220
# Epoch 5/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.4116 - accuracy: 0.8414 - val_loss: 0.3474 - val_accuracy: 0.8465
# Epoch 6/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.3490 - accuracy: 0.8699 - val_loss: 0.2757 - val_accuracy: 0.8764
# Epoch 7/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.2974 - accuracy: 0.8910 - val_loss: 0.2638 - val_accuracy: 0.8845
# Epoch 8/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.2643 - accuracy: 0.9010 - val_loss: 0.2302 - val_accuracy: 0.8995
# Epoch 9/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.2417 - accuracy: 0.9101 - val_loss: 0.1846 - val_accuracy: 0.9253
# Epoch 10/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.2125 - accuracy: 0.9196 - val_loss: 0.1723 - val_accuracy: 0.9035
# Epoch 11/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1881 - accuracy: 0.9270 - val_loss: 0.1643 - val_accuracy: 0.9293
# Epoch 12/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1808 - accuracy: 0.9300 - val_loss: 0.1622 - val_accuracy: 0.9253
# Epoch 13/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1689 - accuracy: 0.9359 - val_loss: 0.1435 - val_accuracy: 0.9198
# Epoch 14/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1620 - accuracy: 0.9386 - val_loss: 0.1485 - val_accuracy: 0.9280
# Epoch 15/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1614 - accuracy: 0.9373 - val_loss: 0.1378 - val_accuracy: 0.9321
# Epoch 16/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1512 - accuracy: 0.9427 - val_loss: 0.1700 - val_accuracy: 0.9062
# Epoch 17/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1484 - accuracy: 0.9426 - val_loss: 0.1370 - val_accuracy: 0.9307
# Epoch 18/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1387 - accuracy: 0.9466 - val_loss: 0.1636 - val_accuracy: 0.9253
# Epoch 19/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1456 - accuracy: 0.9444 - val_loss: 0.1277 - val_accuracy: 0.9253
# Epoch 20/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1329 - accuracy: 0.9486 - val_loss: 0.1307 - val_accuracy: 0.9334
# Epoch 21/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1292 - accuracy: 0.9521 - val_loss: 0.1384 - val_accuracy: 0.9307
# Epoch 22/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1276 - accuracy: 0.9500 - val_loss: 0.1435 - val_accuracy: 0.9280
# Epoch 23/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1273 - accuracy: 0.9488 - val_loss: 0.1185 - val_accuracy: 0.9171
# Epoch 24/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1258 - accuracy: 0.9492 - val_loss: 0.1159 - val_accuracy: 0.9307
# Epoch 25/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1233 - accuracy: 0.9512 - val_loss: 0.1155 - val_accuracy: 0.9375
# Epoch 26/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1167 - accuracy: 0.9524 - val_loss: 0.1424 - val_accuracy: 0.9307
# Epoch 27/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1188 - accuracy: 0.9497 - val_loss: 0.1327 - val_accuracy: 0.9348
# Epoch 28/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1236 - accuracy: 0.9501 - val_loss: 0.1523 - val_accuracy: 0.9307
# Epoch 29/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1185 - accuracy: 0.9531 - val_loss: 0.1218 - val_accuracy: 0.9375
# Epoch 30/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1133 - accuracy: 0.9548 - val_loss: 0.1364 - val_accuracy: 0.9334
# Epoch 31/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1155 - accuracy: 0.9509 - val_loss: 0.1308 - val_accuracy: 0.9348
# Epoch 32/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1146 - accuracy: 0.9544 - val_loss: 0.1567 - val_accuracy: 0.9253
# Epoch 33/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1128 - accuracy: 0.9544 - val_loss: 0.1107 - val_accuracy: 0.9293
# Epoch 34/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1093 - accuracy: 0.9551 - val_loss: 0.1231 - val_accuracy: 0.9361
# Epoch 35/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1114 - accuracy: 0.9544 - val_loss: 0.1210 - val_accuracy: 0.9375
# Epoch 36/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1089 - accuracy: 0.9562 - val_loss: 0.1206 - val_accuracy: 0.9348
# Epoch 37/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1062 - accuracy: 0.9569 - val_loss: 0.1086 - val_accuracy: 0.9266
# Epoch 38/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1057 - accuracy: 0.9577 - val_loss: 0.1225 - val_accuracy: 0.9361
# Epoch 39/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1062 - accuracy: 0.9568 - val_loss: 0.1353 - val_accuracy: 0.9307
# Epoch 40/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1061 - accuracy: 0.9560 - val_loss: 0.1237 - val_accuracy: 0.9361
# Epoch 41/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1056 - accuracy: 0.9580 - val_loss: 0.1294 - val_accuracy: 0.9348
# Epoch 42/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1070 - accuracy: 0.9578 - val_loss: 0.1153 - val_accuracy: 0.9375
# Epoch 43/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1037 - accuracy: 0.9578 - val_loss: 0.1231 - val_accuracy: 0.9307
# Epoch 44/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1039 - accuracy: 0.9572 - val_loss: 0.1191 - val_accuracy: 0.9334
# Epoch 45/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1028 - accuracy: 0.9580 - val_loss: 0.1090 - val_accuracy: 0.9212
# Epoch 46/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1023 - accuracy: 0.9581 - val_loss: 0.1127 - val_accuracy: 0.9321
# Epoch 47/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1018 - accuracy: 0.9566 - val_loss: 0.1391 - val_accuracy: 0.9348
# Epoch 48/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0990 - accuracy: 0.9593 - val_loss: 0.1112 - val_accuracy: 0.9212
# Epoch 49/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1016 - accuracy: 0.9569 - val_loss: 0.1291 - val_accuracy: 0.9361
# Epoch 50/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1024 - accuracy: 0.9583 - val_loss: 0.1172 - val_accuracy: 0.9171
# Epoch 51/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1009 - accuracy: 0.9578 - val_loss: 0.1517 - val_accuracy: 0.9334
# Epoch 52/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1086 - accuracy: 0.9547 - val_loss: 0.1377 - val_accuracy: 0.9348
# Epoch 53/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0970 - accuracy: 0.9587 - val_loss: 0.1312 - val_accuracy: 0.9375
# Epoch 54/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0990 - accuracy: 0.9593 - val_loss: 0.1320 - val_accuracy: 0.9389
# Epoch 55/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0950 - accuracy: 0.9613 - val_loss: 0.1036 - val_accuracy: 0.9321
# Epoch 56/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0942 - accuracy: 0.9618 - val_loss: 0.1288 - val_accuracy: 0.9348
# Epoch 57/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0951 - accuracy: 0.9575 - val_loss: 0.1444 - val_accuracy: 0.9361
# Epoch 58/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0953 - accuracy: 0.9606 - val_loss: 0.1005 - val_accuracy: 0.9375
# Epoch 59/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0909 - accuracy: 0.9604 - val_loss: 0.1201 - val_accuracy: 0.9212
# Epoch 60/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0944 - accuracy: 0.9602 - val_loss: 0.1082 - val_accuracy: 0.9361
# Epoch 61/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0905 - accuracy: 0.9607 - val_loss: 0.1214 - val_accuracy: 0.9226
# Epoch 62/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0873 - accuracy: 0.9616 - val_loss: 0.1210 - val_accuracy: 0.9375
# Epoch 63/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0878 - accuracy: 0.9601 - val_loss: 0.1192 - val_accuracy: 0.9212
# Epoch 64/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0863 - accuracy: 0.9631 - val_loss: 0.1621 - val_accuracy: 0.9348
# Epoch 65/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0895 - accuracy: 0.9612 - val_loss: 0.1254 - val_accuracy: 0.9402
# Epoch 66/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0855 - accuracy: 0.9609 - val_loss: 0.1086 - val_accuracy: 0.9212
# Epoch 67/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0888 - accuracy: 0.9631 - val_loss: 0.1438 - val_accuracy: 0.9253
# Epoch 68/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0868 - accuracy: 0.9621 - val_loss: 0.1420 - val_accuracy: 0.9361
# Epoch 69/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0876 - accuracy: 0.9622 - val_loss: 0.1311 - val_accuracy: 0.9361
# Epoch 70/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0856 - accuracy: 0.9625 - val_loss: 0.1157 - val_accuracy: 0.9334
# Epoch 71/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0815 - accuracy: 0.9625 - val_loss: 0.1213 - val_accuracy: 0.9389
# Epoch 72/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0837 - accuracy: 0.9652 - val_loss: 0.1362 - val_accuracy: 0.9375
# Epoch 73/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0828 - accuracy: 0.9624 - val_loss: 0.1367 - val_accuracy: 0.9375
# Epoch 74/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0808 - accuracy: 0.9660 - val_loss: 0.1402 - val_accuracy: 0.9198
# Epoch 75/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0775 - accuracy: 0.9646 - val_loss: 0.1437 - val_accuracy: 0.9375
# Epoch 76/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0802 - accuracy: 0.9631 - val_loss: 0.1187 - val_accuracy: 0.9402
# Epoch 77/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0784 - accuracy: 0.9663 - val_loss: 0.0879 - val_accuracy: 0.9429
# Epoch 78/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0829 - accuracy: 0.9640 - val_loss: 0.0970 - val_accuracy: 0.9348
# Epoch 79/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0845 - accuracy: 0.9595 - val_loss: 0.1224 - val_accuracy: 0.9389
# Epoch 80/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0801 - accuracy: 0.9652 - val_loss: 0.1322 - val_accuracy: 0.9375
# Epoch 81/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0788 - accuracy: 0.9630 - val_loss: 0.1247 - val_accuracy: 0.9389
# Epoch 82/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0753 - accuracy: 0.9667 - val_loss: 0.0907 - val_accuracy: 0.9538
# Epoch 83/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0764 - accuracy: 0.9661 - val_loss: 0.1013 - val_accuracy: 0.9429
# Epoch 84/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0792 - accuracy: 0.9630 - val_loss: 0.1128 - val_accuracy: 0.9389
# Epoch 85/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0761 - accuracy: 0.9640 - val_loss: 0.1293 - val_accuracy: 0.9361
# Epoch 86/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0772 - accuracy: 0.9648 - val_loss: 0.1330 - val_accuracy: 0.9321
# Epoch 87/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0747 - accuracy: 0.9661 - val_loss: 0.0950 - val_accuracy: 0.9470
# Epoch 88/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0788 - accuracy: 0.9657 - val_loss: 0.0986 - val_accuracy: 0.9226
# Epoch 89/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0746 - accuracy: 0.9667 - val_loss: 0.1440 - val_accuracy: 0.9389
# Epoch 90/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0729 - accuracy: 0.9669 - val_loss: 0.1096 - val_accuracy: 0.9239
# Epoch 91/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0763 - accuracy: 0.9651 - val_loss: 0.1567 - val_accuracy: 0.9389
# Epoch 92/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0731 - accuracy: 0.9663 - val_loss: 0.1490 - val_accuracy: 0.9375
# Epoch 93/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0712 - accuracy: 0.9666 - val_loss: 0.1378 - val_accuracy: 0.9389
# Epoch 94/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0763 - accuracy: 0.9657 - val_loss: 0.0951 - val_accuracy: 0.9361
# Epoch 95/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0685 - accuracy: 0.9681 - val_loss: 0.1343 - val_accuracy: 0.9389
# Epoch 96/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0669 - accuracy: 0.9686 - val_loss: 0.1409 - val_accuracy: 0.9375
# Epoch 97/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0708 - accuracy: 0.9678 - val_loss: 0.1829 - val_accuracy: 0.9334
# Epoch 98/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0707 - accuracy: 0.9674 - val_loss: 0.1316 - val_accuracy: 0.9402
# Epoch 99/200
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0705 - accuracy: 0.9657 - val_loss: 0.1806 - val_accuracy: 0.9185
# Epoch 100/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0694 - accuracy: 0.9642 - val_loss: 0.1022 - val_accuracy: 0.9402
# Epoch 101/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0667 - accuracy: 0.9698 - val_loss: 0.1425 - val_accuracy: 0.9389
# Epoch 102/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0704 - accuracy: 0.9680 - val_loss: 0.0899 - val_accuracy: 0.9497
# Epoch 103/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0684 - accuracy: 0.9686 - val_loss: 0.1787 - val_accuracy: 0.8736
# Epoch 104/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0672 - accuracy: 0.9692 - val_loss: 0.1486 - val_accuracy: 0.9389
# Epoch 105/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0653 - accuracy: 0.9702 - val_loss: 0.1347 - val_accuracy: 0.9389
# Epoch 106/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0665 - accuracy: 0.9674 - val_loss: 0.1410 - val_accuracy: 0.9402
# Epoch 107/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0656 - accuracy: 0.9684 - val_loss: 0.1351 - val_accuracy: 0.9361
# Epoch 108/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0659 - accuracy: 0.9692 - val_loss: 0.1450 - val_accuracy: 0.9389
# Epoch 109/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0676 - accuracy: 0.9680 - val_loss: 0.0863 - val_accuracy: 0.9592
# Epoch 110/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0704 - accuracy: 0.9670 - val_loss: 0.1366 - val_accuracy: 0.9375
# Epoch 111/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0681 - accuracy: 0.9687 - val_loss: 0.1081 - val_accuracy: 0.9443
# Epoch 112/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0678 - accuracy: 0.9674 - val_loss: 0.1084 - val_accuracy: 0.9484
# Epoch 113/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0691 - accuracy: 0.9701 - val_loss: 0.1739 - val_accuracy: 0.9022
# Epoch 114/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0676 - accuracy: 0.9696 - val_loss: 0.1510 - val_accuracy: 0.9212
# Epoch 115/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0632 - accuracy: 0.9707 - val_loss: 0.1471 - val_accuracy: 0.9185
# Epoch 116/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0667 - accuracy: 0.9681 - val_loss: 0.1911 - val_accuracy: 0.9307
# Epoch 117/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0641 - accuracy: 0.9708 - val_loss: 0.1433 - val_accuracy: 0.9348
# Epoch 118/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0604 - accuracy: 0.9732 - val_loss: 0.1734 - val_accuracy: 0.9171
# Epoch 119/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0670 - accuracy: 0.9695 - val_loss: 0.1735 - val_accuracy: 0.9158
# Epoch 120/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0612 - accuracy: 0.9708 - val_loss: 0.1524 - val_accuracy: 0.9185
# Epoch 121/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0627 - accuracy: 0.9723 - val_loss: 0.0911 - val_accuracy: 0.9457
# Epoch 122/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0603 - accuracy: 0.9717 - val_loss: 0.1295 - val_accuracy: 0.9416
# Epoch 123/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0615 - accuracy: 0.9710 - val_loss: 0.1456 - val_accuracy: 0.9334
# Epoch 124/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0625 - accuracy: 0.9714 - val_loss: 0.1172 - val_accuracy: 0.9402
# Epoch 125/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0604 - accuracy: 0.9725 - val_loss: 0.1079 - val_accuracy: 0.9429
# Epoch 126/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0645 - accuracy: 0.9684 - val_loss: 0.1125 - val_accuracy: 0.9565
# Epoch 127/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0602 - accuracy: 0.9711 - val_loss: 0.1063 - val_accuracy: 0.9389
# Epoch 128/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0585 - accuracy: 0.9708 - val_loss: 0.1598 - val_accuracy: 0.9361
# Epoch 129/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0562 - accuracy: 0.9751 - val_loss: 0.1859 - val_accuracy: 0.9158
# Epoch 130/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0590 - accuracy: 0.9713 - val_loss: 0.1311 - val_accuracy: 0.9389
# Epoch 131/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0618 - accuracy: 0.9711 - val_loss: 0.1560 - val_accuracy: 0.9117
# Epoch 132/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0604 - accuracy: 0.9710 - val_loss: 0.1672 - val_accuracy: 0.9348
# Epoch 133/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0601 - accuracy: 0.9713 - val_loss: 0.1389 - val_accuracy: 0.9416
# Epoch 134/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0593 - accuracy: 0.9713 - val_loss: 0.1041 - val_accuracy: 0.9538
# Epoch 135/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0598 - accuracy: 0.9713 - val_loss: 0.1307 - val_accuracy: 0.9334
# Epoch 136/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0579 - accuracy: 0.9711 - val_loss: 0.1620 - val_accuracy: 0.9361
# Epoch 137/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0600 - accuracy: 0.9728 - val_loss: 0.1476 - val_accuracy: 0.9185
# Epoch 138/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0558 - accuracy: 0.9725 - val_loss: 0.1179 - val_accuracy: 0.9429
# Epoch 139/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0594 - accuracy: 0.9716 - val_loss: 0.1352 - val_accuracy: 0.9375
# Epoch 140/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0598 - accuracy: 0.9713 - val_loss: 0.1255 - val_accuracy: 0.9375
# Epoch 141/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0583 - accuracy: 0.9711 - val_loss: 0.1301 - val_accuracy: 0.9416
# Epoch 142/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0571 - accuracy: 0.9716 - val_loss: 0.1252 - val_accuracy: 0.9226
# Epoch 143/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0590 - accuracy: 0.9713 - val_loss: 0.1065 - val_accuracy: 0.9538
# Epoch 144/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0588 - accuracy: 0.9707 - val_loss: 0.1391 - val_accuracy: 0.9375
# Epoch 145/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0585 - accuracy: 0.9729 - val_loss: 0.1160 - val_accuracy: 0.9592
# Epoch 146/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0546 - accuracy: 0.9742 - val_loss: 0.1522 - val_accuracy: 0.9389
# Epoch 147/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0559 - accuracy: 0.9735 - val_loss: 0.1109 - val_accuracy: 0.9429
# Epoch 148/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0640 - accuracy: 0.9713 - val_loss: 0.1512 - val_accuracy: 0.9402
# Epoch 149/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0594 - accuracy: 0.9734 - val_loss: 0.1525 - val_accuracy: 0.9185
# Epoch 150/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0572 - accuracy: 0.9732 - val_loss: 0.1223 - val_accuracy: 0.9443
# Epoch 151/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0566 - accuracy: 0.9726 - val_loss: 0.1548 - val_accuracy: 0.9389
# Epoch 152/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0521 - accuracy: 0.9758 - val_loss: 0.0943 - val_accuracy: 0.9633
# Epoch 153/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0560 - accuracy: 0.9735 - val_loss: 0.1687 - val_accuracy: 0.9334
# Epoch 154/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0535 - accuracy: 0.9761 - val_loss: 0.1372 - val_accuracy: 0.9375
# Epoch 155/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0515 - accuracy: 0.9764 - val_loss: 0.0948 - val_accuracy: 0.9457
# Epoch 156/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0539 - accuracy: 0.9740 - val_loss: 0.1025 - val_accuracy: 0.9443
# Epoch 157/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0543 - accuracy: 0.9746 - val_loss: 0.1195 - val_accuracy: 0.9429
# Epoch 158/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0535 - accuracy: 0.9767 - val_loss: 0.1168 - val_accuracy: 0.9511
# Epoch 159/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0568 - accuracy: 0.9731 - val_loss: 0.1046 - val_accuracy: 0.9429
# Epoch 160/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0491 - accuracy: 0.9773 - val_loss: 0.1657 - val_accuracy: 0.9293
# Epoch 161/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0585 - accuracy: 0.9732 - val_loss: 0.1580 - val_accuracy: 0.9307
# Epoch 162/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0630 - accuracy: 0.9711 - val_loss: 0.1325 - val_accuracy: 0.9185
# Epoch 163/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0545 - accuracy: 0.9751 - val_loss: 0.1188 - val_accuracy: 0.9606
# Epoch 164/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0539 - accuracy: 0.9749 - val_loss: 0.1680 - val_accuracy: 0.9402
# Epoch 165/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0536 - accuracy: 0.9746 - val_loss: 0.2010 - val_accuracy: 0.9307
# Epoch 166/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0549 - accuracy: 0.9748 - val_loss: 0.2782 - val_accuracy: 0.8696
# Epoch 167/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0583 - accuracy: 0.9719 - val_loss: 0.0968 - val_accuracy: 0.9524
# Epoch 168/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0571 - accuracy: 0.9734 - val_loss: 0.1865 - val_accuracy: 0.9307
# Epoch 169/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0576 - accuracy: 0.9748 - val_loss: 0.1607 - val_accuracy: 0.9348
# Epoch 170/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0513 - accuracy: 0.9755 - val_loss: 0.1565 - val_accuracy: 0.9416
# Epoch 171/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0520 - accuracy: 0.9742 - val_loss: 0.2469 - val_accuracy: 0.8682
# Epoch 172/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0507 - accuracy: 0.9752 - val_loss: 0.1078 - val_accuracy: 0.9620
# Epoch 173/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0492 - accuracy: 0.9761 - val_loss: 0.0780 - val_accuracy: 0.9497
# Epoch 174/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0538 - accuracy: 0.9737 - val_loss: 0.1942 - val_accuracy: 0.9144
# Epoch 175/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0522 - accuracy: 0.9751 - val_loss: 0.1482 - val_accuracy: 0.9375
# Epoch 176/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0502 - accuracy: 0.9754 - val_loss: 0.1506 - val_accuracy: 0.9266
# Epoch 177/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0483 - accuracy: 0.9764 - val_loss: 0.1807 - val_accuracy: 0.9321
# Epoch 178/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0511 - accuracy: 0.9745 - val_loss: 0.2103 - val_accuracy: 0.9307
# Epoch 179/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0518 - accuracy: 0.9761 - val_loss: 0.1682 - val_accuracy: 0.9389
# Epoch 180/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0484 - accuracy: 0.9775 - val_loss: 0.1290 - val_accuracy: 0.9348
# Epoch 181/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0515 - accuracy: 0.9760 - val_loss: 0.2524 - val_accuracy: 0.9321
# Epoch 182/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0516 - accuracy: 0.9749 - val_loss: 0.2255 - val_accuracy: 0.8940
# Epoch 183/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0479 - accuracy: 0.9766 - val_loss: 0.1712 - val_accuracy: 0.9198
# Epoch 184/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0466 - accuracy: 0.9778 - val_loss: 0.1426 - val_accuracy: 0.9552
# Epoch 185/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0453 - accuracy: 0.9778 - val_loss: 0.1987 - val_accuracy: 0.9389
# Epoch 186/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0526 - accuracy: 0.9751 - val_loss: 0.1983 - val_accuracy: 0.9171
# Epoch 187/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0569 - accuracy: 0.9743 - val_loss: 0.0870 - val_accuracy: 0.9457
# Epoch 188/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0530 - accuracy: 0.9739 - val_loss: 0.1887 - val_accuracy: 0.8913
# Epoch 189/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0508 - accuracy: 0.9758 - val_loss: 0.1365 - val_accuracy: 0.9457
# Epoch 190/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0513 - accuracy: 0.9735 - val_loss: 0.1364 - val_accuracy: 0.9457
# Epoch 191/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0464 - accuracy: 0.9764 - val_loss: 0.2249 - val_accuracy: 0.9361
# Epoch 192/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0474 - accuracy: 0.9787 - val_loss: 0.0877 - val_accuracy: 0.9497
# Epoch 193/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0465 - accuracy: 0.9782 - val_loss: 0.1651 - val_accuracy: 0.9429
# Epoch 194/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0470 - accuracy: 0.9781 - val_loss: 0.1112 - val_accuracy: 0.9470
# Epoch 195/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0508 - accuracy: 0.9760 - val_loss: 0.1579 - val_accuracy: 0.9375
# Epoch 196/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0487 - accuracy: 0.9761 - val_loss: 0.1342 - val_accuracy: 0.9443
# Epoch 197/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0466 - accuracy: 0.9782 - val_loss: 0.1349 - val_accuracy: 0.9389
# Epoch 198/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0470 - accuracy: 0.9772 - val_loss: 0.0617 - val_accuracy: 0.9823
# Epoch 199/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0481 - accuracy: 0.9755 - val_loss: 0.1725 - val_accuracy: 0.9348
# Epoch 200/200
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0476 - accuracy: 0.9779 - val_loss: 0.1596 - val_accuracy: 0.9457

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, 201)
plt.plot(epochs, loss_values, 'b', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.figure(figsize=(15,10))
plt.show()

# %%
model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# x (InputLayer)                  [(None, 1, 32, 36)]  0
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 30, 34)   320         x[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_52 (MaxPooling2D) (None, 16, 15, 34)   0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# dropout_143 (Dropout)           (None, 16, 15, 34)   0           max_pooling2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 14, 13, 32)   9824        dropout_143[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_53 (MaxPooling2D) (None, 7, 6, 32)     0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# dropout_144 (Dropout)           (None, 7, 6, 32)     0           max_pooling2d_53[0][0]
# __________________________________________________________________________________________________
# flatten_26 (Flatten)            (None, 1344)         0           dropout_144[0][0]
# __________________________________________________________________________________________________
# dense_113 (Dense)               (None, 64)           86080       flatten_26[0][0]
# __________________________________________________________________________________________________
# dropout_145 (Dropout)           (None, 64)           0           dense_113[0][0]
# __________________________________________________________________________________________________
# x_sigma (InputLayer)            [(None, 153)]        0
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 217)          0           dropout_145[0][0]
#                                                                  x_sigma[0][0]
# __________________________________________________________________________________________________
# dense_120 (Dense)               (None, 64)           13952       concatenate_12[0][0]
# __________________________________________________________________________________________________
# dense_121 (Dense)               (None, 6)            390         dense_120[0][0]
# ==================================================================================================
# Total params: 110,566
# Trainable params: 110,566
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
predictions= model.predict({'x': X_test, 'x_new': X_test_new, 'x_sigma': X_test_sigma})
y_pred = [np.argmax(x) for x in predictions]
y_test = y_test.reshape(-1)
(y_pred == y_test).mean()
# Out:
# 0.9155072955548015

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96       496
#            1       0.98      0.95      0.96       471
#            2       0.91      1.00      0.95       420
#            3       0.82      0.77      0.80       491
#            4       0.81      0.84      0.83       532
#            5       1.00      1.00      1.00       537
#
#     accuracy                           0.92      2947
#    macro avg       0.92      0.92      0.92      2947
# weighted avg       0.92      0.92      0.92      2947

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

y_score = predictions

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(Y_test_new[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
lw = 2
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

# Plot all ROC curves
plt.figure(figsize=(13,10))

colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'red', 'green', 'black'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve of fully connected neural network')
plt.legend(loc="lower right")
plt.show()
